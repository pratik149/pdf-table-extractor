# %%
from tabula import read_pdf

# %%
df=read_pdf("abc.pdf")

# %%
df.fillna("", inplace = True)

# %%
df
# Out:
#                                         Aluminium  US$/lb    0.84   0.86  \
# 0                                                   US$/t   1,850  1,906
# 1                           vs. previous forecast       %
# 2                                          Copper  US$/lb    2.65   2.56
# 3                                                   US$/t   5,833  5,653
# 4                           vs. previous forecast       %
# 5                                          Nickel  US$/lb    4.65   4.18
# 6                                                   US$/t  10,261  9,223
# 7                           vs. previous forecast       %
# 8                                            Zinc  US$/lb    1.26   1.17
# 9                                                   US$/t   2,775  2,583
# 10                          vs. previous forecast       %
# 11                                           Gold  US$/oz   1,218  1,259
# 12                          vs. previous forecast       %
# ...
